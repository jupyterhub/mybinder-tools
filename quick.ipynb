# %%
from kubetools import get_all, delete, top, get_gcloud_node_info
from subprocess import check_output
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.max_rows = 999

# %%
get_all('pod')
# Out:
#                                                   name ready  \
# 0                              binder-5b8b4479cb-ffc88   1/1
# 1           build-gbonomib-2dmlteachings-358c59-f7fb38   0/1
# 2    build-psicobyte-2dpython-5fdesde-5f0-b4334f-d3...   0/1
# 3                                 hub-6cfd8bf669-z5vl6   1/1
# 4       jupyter-abubakrsec-2dpythontutorial-2dvaj6ppov   0/1
# 5    jupyter-asetoodehnia-2din-2d-2dto-2dai-2dworks...   1/1
# 6    jupyter-asetoodehnia-2din-2d-2dto-2dai-2dworks...   1/1
# 7    jupyter-binder-2dexamples-2djulia-2dpython-2d0...   1/1
# 8    jupyter-binder-2dexamples-2djulia-2dpython-2da...   1/1
# 9    jupyter-binder-2dexamples-2djulia-2dpython-2dc...   1/1
# 10   jupyter-binder-2dexamples-2djulia-2dpython-2dc...   1/1
# 11   jupyter-binder-2dexamples-2djulia-2dpython-2dd...   1/1
# 12   jupyter-binder-2dexamples-2djulia-2dpython-2df...   1/1
# 13   jupyter-binder-2dexamples-2djupyter-2dstacks-2...   1/1
# ...

# %%
get_all('pod').query('kind == "hub"')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda/envs/dev/lib/python3.5/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     384         try:
# --> 385             stdout, stderr = process.communicate(input, timeout=timeout)
#     386         except TimeoutExpired:
#
# ~/anaconda/envs/dev/lib/python3.5/subprocess.py in communicate(self, input, timeout)
#     789             elif self.stdout:
# --> 790                 stdout = self.stdout.read()
#     791                 self.stdout.close()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ProcessLookupError                        Traceback (most recent call last)
# <ipython-input-4-2a713d57ba13> in <module>()
# ----> 1 get_all('pod').query('kind == "hub"')
#
# ...
